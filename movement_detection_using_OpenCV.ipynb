# %%
import cv2

def main():
    
    # Capture the video   
    image_path = 'C:/Users/Crazyguy/Documents/Bandicam/nasha_mukti_pakdo.mp4'
    cap = cv2.VideoCapture(image_path)
    video_out = image_path[:-4] + '_detected' + image_path[-4:]
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(fps)
    
    nb_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    print(frame_h)
    print(frame_w)
    
    video_writer = cv2.VideoWriter(video_out, 
                                   cv2.VideoWriter_fourcc(*'MPEG'), 
                                   30.0, 
                                   (frame_w, frame_h))
    
    # Reading two frames from camera
    ret, frame1 = cap.read()
    ret, frame2 = cap.read()


    while ret:
        
        # Calculate the absolute difference between frames
        framediff = cv2.absdiff(frame1, frame2)
        
	# Converting the frames into grayscale
        grey = cv2.cvtColor(framediff, cv2.COLOR_BGR2GRAY)
        
	# Calculating the threshold value at thresh_value = 20 and converting it to two color mode using THRESH_BINARY
        ret, thresh = cv2.threshold( grey, 20, 255, cv2.THRESH_BINARY)
        
	# finding contours
        contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
	
	# Draw contours
        cv2.drawContours(frame2, contours, -1, (0, 0, 255), 2)

        cv2.imshow("Original", frame1)
        #cv2.resizeWindow('Original', 850, 500)
        cv2.imshow("Output", frame2)
        video_writer.write(np.uint8(frame2))
            
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        
        frame2 = frame1
        ret, frame1 = cap.read()

    cv2.destroyAllWindows()
    cap.release()
    video_writer.release()

if __name__ == "__main__":
    main()
